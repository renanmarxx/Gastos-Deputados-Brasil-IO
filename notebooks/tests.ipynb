# %%
import pandas as pd

# %%
file_path = "../data/cota_parlamentar.csv"

df = pd.read_csv(file_path, sep=",", encoding="utf-8")
df.head()

# %%
df.info()

# %%
url = "https://brasil.io/dataset/gastos-deputados/cota_parlamentar/"

metadados = pd.read_html(url)

metadados
