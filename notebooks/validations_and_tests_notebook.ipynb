# %% [markdown]
# #### Run the `brasil_io.py` script to retrieve the `.csv` file

# %%
# !python ../scripts/brasil_io.py

# %% [markdown]
# #### Create a Pandas DataFrame with the `.csv` extracted file

# %%
import pandas as pd
data = pd.read_csv('../data/gastos-deputados_cota_parlamentar.csv', nrows=None, compression='gzip',
                   on_bad_lines='warn')
data.head()

# %%
data.info()
