# %%
# !python brasil_io.py

# %%
import pandas as pd
data = pd.read_csv('data/gastos-deputados_cota_parlamentar.csv.gz', nrows=None, compression='gzip',
                   on_bad_lines='warn')
data.head()
# Out:
#    codlegislatura           datemissao  idedocumento  idecadastro  \
# 0              56  2020-02-01 00:00:00       7007086          NaN
# 1              56  2020-02-13 00:00:00       7017162          NaN
# 2              56  2020-02-04 00:00:00       7007754          NaN
# 3              56  2020-02-18 00:00:00       7018634          NaN
# 4              56  2020-02-11 00:00:00       7011106          NaN
#
#    indtipodocumento  nucarteiraparlamentar  nudeputadoid  nulegislatura  \
# 0                 0                    NaN          2442           2019
# 1                 4                    NaN          2442           2019
# 2                 4                    NaN          2442           2019
# 3                 4                    NaN          2442           2019
# 4                 4                    NaN          2442           2019
#
#    numano  numespecificacaosubcota  ...  \
# 0    2020                        0  ...
# 1    2020                        0  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3855649 entries, 0 to 3855648
# Data columns (total 29 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   codlegislatura             int64
#  1   datemissao                 object
#  2   idedocumento               int64
#  3   idecadastro                float64
#  4   indtipodocumento           int64
#  5   nucarteiraparlamentar      float64
#  6   nudeputadoid               int64
#  7   nulegislatura              int64
#  8   numano                     int64
#  9   numespecificacaosubcota    int64
#  10  numlote                    int64
#  11  nummes                     int64
#  12  numparcela                 int64
#  13  numressarcimento           float64
#  14  numsubcota                 int64
#  15  sgpartido                  object
#  16  sguf                       object
#  17  txnomeparlamentar          object
#  18  txtcnpjcpf                 int64
# ...
